# %% [markdown]
# <a href="https://colab.research.google.com/github/andrybrew/all-files/blob/master/WAAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = open(r'./MBTI.txt',mode='r',encoding="utf8")
data = file.read()
file.close()
data
# Out:
# '8/9/18, 13:49 - Ratih FEB: <Media omitted>\n8/9/18, 13:50 - tieka imt: Wkwkwkwkwk... resmi sudah...\n8/9/18, 13:50 - tieka imt: 👏🏻👏🏻👏🏻👏🏻\n8/9/18, 13:55 - Ratih FEB: Pak Deden ada salam dari Prof. Anis\n8/9/18, 13:56 - Herry Irawan: Manteppp...\n8/9/18, 13:56 - Herry Irawan: Sy bisa perawatan wajah lbh dekat...😊😊😊\n8/9/18, 14:01 - ineu jenong: Pak herry, ternyata ☺\n8/9/18, 14:06 - ANDRY BREW: wah nu skin. kulit baru?, mau dong beli..\n8/9/18, 14:16 - ineu jenong: kokoh dan pak deden ada calon downline nih... Siapa cepat dia dapat\n8/9/18, 14:22 - ANDRY BREW: donlain jaket kulit tas kulit\n8/9/18, 14:25 - ineu jenong: 😄\n8/10/18, 08:00 - elvira imt: Temans.. \nBerhubung hari ini adlh deadline buat input kode dosen pengampu maka mohon dengan sangat agar bisa dikirim hari ini sblm jam 14🙏🏻🙏🏻..\n\nYg blm ada rekapan:\n1. Mgt operasi dan kualitas\n2. Mgt pemasaran\n3. Mgt keuangan\n4. Kewirausahaan\n5. Mgt pengetahuan\n6. Mgt usaha baru\n7. Mgt keu int\n8. Hukum dan regulasi\n\nDitunggu 
# ...

# %%
pattern = re.compile('\d+:\d+\s+-\s+([a-zA-Z0-9]+\s?[a-zA-Z0-9]+\s?[a-zA-Z0-9]+\s?):\s+')
messengers = re.findall(pattern,data)

# %%
count_messages={}
for each in messengers:
    if each in count_messages.keys():
        count_messages[each]+=1
    else:
        count_messages[each]=1
count_messages
# Out:
# {'ANDRY BREW': 288,
#  'Ama Telu': 160,
#  'Andrieta Shintia Telu': 30,
#  'Dama TelU': 61,
#  'Dian FEB SDM': 130,
#  'Dodie Tri': 69,
#  'Helni IMT': 142,
#  'Herry Irawan': 356,
#  'Irni IMT': 81,
#  'Mediani Imt': 20,
#  'Mia Sugiat': 16,
#  'Ola Imt': 747,
#  'Osa Omar Sharif': 60,
#  'Ratih FEB': 166,
#  'Risris FEB': 29,
#  'Sisca Eka': 30,
#  'Siska Marhen': 88,
#  'Sony': 31,
#  'Suparwoto FEB': 601,
#  'Tri Denok FEB': 115,
#  'Yudha FEB': 87,
#  'abdullah imt': 67,
#  'arif partono imt': 1939,
#  'astri ghina': 54,
#  'astri krisnawati': 92,
#  'azhari imt': 62,
#  'brady imt': 98,
#  'cahyono IMT': 2,
#  'candiwan imt': 62,
#  'eka': 22,
#  'elvira imt': 329,
#  'endang sofyan feb': 27,
#  'erni IMT': 39,
#  'fajar imt': 14,
#  'fetty imt': 22,
#  'firli feb': 2,
#  'grisna imt': 76,
#  'hani gita feb': 117,
#  'iin indrawati imt': 11,
#  'indira imt': 85,
#  'ineu jenong': 410,
#  'jurry imt': 31,
#  'khairani FEB': 28,
#  'lia IMT': 113,
#  'maya IMT': 687,
# ...

# %%
messages_split = pattern.split(data)
messages_split[9:11]
# Out:
# ['Ratih FEB', 'Waalaikumsalam. Siap Bu, terimakasih info nya\n3/18/20, ']

# %%
pd1 = pd.DataFrame(count_messages)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-435e7a23ce00> in <module>()
# ----> 1 pd1 = pd.DataFrame(count_messages)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ...
